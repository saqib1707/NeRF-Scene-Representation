# %% [markdown]
# (a) What is a radiance field? What information is included in a radiance field? How is neural
# radiance field (NeRF) different?
#
# A radiance field is a function that describes how light transport occurs through a 3D volume. It describes the direction of light rays moving through every $x=(x, y, z)$ coordinate in space and in every direction $d$, described either as $\theta$ and $\phi$ angles or a unit vector. Collectively they form a 5D feature space that describes light transport in a 3D scene.
#
# The NeRF, inspired by this representation, attempts to approximate a function that maps from this space into a 4D space consisting of color $c=(R,G,B)$ and a density $\sigma$, which you can think of as the likelihood that the light ray at this 5D coordinate space is terminated (e.g. by occlusion). The standard NeRF is thus a function of the form $F_\theta : (x,d) \rightarrow (c,\sigma)$.

# %% [markdown]
# (b) What is ray marching? Given a radiance field, how is each pixel calculated? (This is called the render equation.) Write down your render equation in a concrete math expression with clarified notations.

# %% [markdown]
# (c) What is positional encoding? What is the purpose of positional encoding in NeRF models? Train your model without positional encoding and compare the results. You need to show atleast two pairs of examples.

# %% [markdown]
# (d) Is it possible to extract scene geometry (e.g. depth) information from a trained NeRF model? Describe your method in detail. Implement your method and show two depth maps generated by your method.

# %% [markdown]
# (e) What are the major issues you find when using NeRF? List at least 2 drawbacks. For each of them, propose a possible improvement. You are encouraged to check follow-up papers of NeRF, but you should cite these works if borrowing their ideas.

# %% [markdown]
# ## References
#
# - https://towardsdatascience.com/its-nerf-from-nothing-build-a-vanilla-nerf-with-pytorch-7846e4c45666
